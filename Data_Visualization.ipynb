# %% [markdown]
# <a href="https://colab.research.google.com/github/ianplace08/Py_Udemy/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Univariate and Multivariate visualization
#
# * Histograms
#
# * bimodal
#
# * skewed
#
# * uniform distribution

# %% [markdown]
# DENSITY PLOTS
#
# * Kernel density plots
#
# * the density distribution have similar shapes as the las 3 mentioned before.

# %% [markdown]
# BOX PLOTS
#
# * median
# * upper and lower quartiles
# * interquartile range
# * outliers

# %% [markdown]
# CATEGORICAL FEATURES
#
# * Have a fixed set of values
# * Each of these values assigns an observation to a corresponding group, known as category.
# * Binary variables only have 2 possibles values
# * Plots for categorical features: frequency table and bar plot.

# %% [markdown]
# MULTIVARIATE VISUALIZATION: NUMERICAL VS NUMERICAL
#
# * Visualize relationship between two numerical features in a data set.
# * Type of plot depend on data type of features.
# * Plots: scatter plot, correlation matrix

# %% [markdown]
# PYTHON LIBRARIES FOR DATA VISUALIZATION
#
# * Matplotlib
# * Pandas visualization
# * Seaborn

# %% [markdown]
# ![Captura de Pantalla 2022-08-05 a la(s) 15.19.01.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
