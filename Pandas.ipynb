# %% [markdown]
# <a href="https://colab.research.google.com/github/ianplace08/Py_Udemy/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.__version__
# Out:
# '1.3.5'

# %% [markdown]
# DATAFRAMES

# %%
data =  {"Country": ["Belgium", "India", "Brazil"],
"Capital": ["Brussels", "New Delhi", "Brasília"],
"Population": [11190846, 1303171035, 207847528]}

# %%
df = pd.DataFrame(data, 
                  columns = ["Country","Capital","Population"])

# %%
df [data]
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %% [markdown]
# SERIES

# %%
## Each column in a DATAFRAME is a Series

ages = pd.Series([22,35,58], name = "Age")
ages
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
ages.max()
# Out:
# 58

# %%
## IMPORT DATA

## df = pd.read_csv()
## df.head() ->>> encabezados, podemos poner un numero
## df.tail() ->>> datos que estan al ultimo, podemos poner un numero.
## df.columns()

# %%
## Rename columns

df.rename(columns={"Country":"Countries",
                   "Capital":"Capitals"})
# Out:
#   Countries   Capitals  Population
# 0   Belgium   Brussels    11190846
# 1     India  New Delhi  1303171035
# 2    Brazil   Brasília   207847528

# %% [markdown]
# EXTRACTING INFORMATION

# %%
df1 = df ["Country"]
df1.head()
# Out:
# 0    Belgium
# 1      India
# 2     Brazil
# Name: Country, dtype: object

# %%
df2 = df[["Country","Capital","Population"]]
df2.head()
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasília   207847528

# %%
##SELECTING ROWS

df.iloc[1:2]
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035

# %%
df.iloc[0:2]
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035

# %%
##Conditional statements

df3 = df[df["Population"]>11190846]
df3.head()
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035
# 2  Brazil   Brasília   207847528

# %%
## Extracting specific columns and rows
## df.iloc[rows,columns]
df.iloc[0:2,0:3]
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035

# %%
df4 = df.loc[df["Population"]>11190846,"Country"]
df4.head()
# Out:
# 1     India
# 2    Brazil
# Name: Country, dtype: object

# %% [markdown]
# AGGREGATING STATISTICS

# %%
df["Population"].mean()
# Out:
# 507403136.3333333

# %%
df["Population"].median()
# Out:
# 207847528.0

# %%
df.describe()
# Out:
#          Population
# count  3.000000e+00
# mean   5.074031e+08
# std    6.961346e+08
# min    1.119085e+07
# 25%    1.095192e+08
# 50%    2.078475e+08
# 75%    7.555093e+08
# max    1.303171e+09

# %%
df["Population"].describe()
# Out:
# count    3.000000e+00
# mean     5.074031e+08
# std      6.961346e+08
# min      1.119085e+07
# 25%      1.095192e+08
# 50%      2.078475e+08
# 75%      7.555093e+08
# max      1.303171e+09
# Name: Population, dtype: float64

# %%
df["Population"].value_counts()
# Out:
# 11190846      1
# 1303171035    1
# 207847528     1
# Name: Population, dtype: int64

# %% [markdown]
# MERGE DATA FRAME

# %% [markdown]
# ![Captura de Pantalla 2022-08-01 a la(s) 19.23.39.png](data:image/png;base64,...)
